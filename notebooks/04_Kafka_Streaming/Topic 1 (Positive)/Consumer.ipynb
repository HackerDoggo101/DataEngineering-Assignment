# %%
## Author: Yam Jason

# %%
from pyspark.sql import SparkSession

spark = SparkSession\
        .builder\
        .appName("Consumer")\
        .getOrCreate()
# Out:
# 24/09/07 15:09:55 WARN Utils: Your hostname, WeirdSmile. resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 24/09/07 15:09:55 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/09/07 15:09:56 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/09/07 15:09:57 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %% [markdown]
# ## Consume Messages

# %%
sc = spark.sparkContext
sc.addFile("../../../de_classes/event_streaming/KafkaConsumer.py")

# %%
from KafkaConsumer import KafkaConsumerClass

# Create an instance of KafkaConsumerClass
positiveConsumer = KafkaConsumerClass(bootstrap_servers='localhost:9092', topic_name='positiveReviews')

# %%
# Consume messages
positiveConsumer.consume_messages()
# Out:
# Received message: {'Positive Review': 'all item are good but get i order'}
# Received message: {'Positive Review': 'good seller delivery man parcel good condition'}
# Received message: {'Positive Review': 'comfortable mask'}
# Received message: {'Positive Review': 'so good'}
# Received message: {'Positive Review': 'best best best'}
# Received message: {'Positive Review': 'v good tq'}
# Received message: {'Positive Review': 'i am so happy i have received goods today i am very satisfied happy'}
# Received message: {'Positive Review': 'fast delivery good quality nice packing will order again'}
# Received message: {'Positive Review': 'received good condition'}
# Received message: {'Positive Review': 'quality so so white face mask layer but grey only layer'}
# Received message: {'Positive Review': 'brg sudah spi dengan safe delivery fast he likes tq seller'}
# Received message: {'Positive Review': 'fast delivery received good condition valuable purchased'}
# ...

# %%
# Close the consumer connection
positiveConsumer.close()

# %%
spark.stop()
